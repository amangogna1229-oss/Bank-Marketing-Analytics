# %%
bank_df = spark.read.csv(
    "Files/bronze/Bank_Enhance_dataset/Bank_Enhance_dataset.csv",
    header=True,
    sep=";",
    inferSchema=True
)
display(bank_df)
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 4, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 7820ce05-555c-4701-a352-e64b1a284603)

# %%
bank_df.printSchema()
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 5, Finished, Available, Finished, False)
# root
#  |-- age: integer (nullable = true)
#  |-- job: string (nullable = true)
#  |-- marital: string (nullable = true)
#  |-- education: string (nullable = true)
#  |-- default: string (nullable = true)
#  |-- housing: string (nullable = true)
#  |-- loan: string (nullable = true)
#  |-- contact: string (nullable = true)
#  |-- month: string (nullable = true)
#  |-- day_of_week: string (nullable = true)
#  |-- duration: integer (nullable = true)
#  |-- campaign: integer (nullable = true)
#  |-- pdays: integer (nullable = true)
#  |-- previous: integer (nullable = true)
#  |-- poutcome: string (nullable = true)
#  |-- emp.var.rate: double (nullable = true)
#  |-- cons.price.idx: double (nullable = true)
#  |-- cons.conf.idx: double (nullable = true)
#  |-- euribor3m: double (nullable = true)
#  |-- nr.employed: double (nullable = true)
#  |-- y: string (nullable = true)
# ...

# %%
bank_df.count()
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 6, Finished, Available, Finished, False)
# 19999

# %%
channel_df = spark.read.csv(
    "Files/bronze/Bank_Enhance_dataset/Bank_Channel.csv",
    header=True,
    inferSchema=True
)
display(channel_df)
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 3fb284a9-da56-441f-8241-60971e7e884a)

# %%
customer_df = spark.read.csv(
    "Files/bronze/Bank_Enhance_dataset/Bank_Customer.csv",
    header=True,
    inferSchema=True
)
display(customer_df)
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 8, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 53b337f8-03dc-444f-997d-2456eb155311)

# %%
region_df = spark.read.csv(
    "Files/bronze/Bank_Enhance_dataset/Bank_Region.csv",
    header=True,
    inferSchema=True
)
display(region_df)
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 9, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c641405e-2af5-446a-8a5d-47a9038281f3)

# %%
bank_df.write.mode("overwrite").format("delta").saveAsTable("bronze_bank_")
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 10, Finished, Available, Finished, False)

# %%
customer_df.write.mode("overwrite").format("delta").saveAsTable("bronze_customer")
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 11, Finished, Available, Finished, False)

# %%
channel_df.write.mode("overwrite").format("delta").saveAsTable("bronze_channel")
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 12, Finished, Available, Finished, False)

# %%
region_df.write.mode("overwrite").format("delta").saveAsTable("bronze_region")
# Out:
# StatementMeta(, a4d005d1-4fc6-41fc-8693-241387f7d109, 13, Finished, Available, Finished, False)

# %%
spark.sql("SHOW TABLES").show()
# Out:
# StatementMeta(, 76791a3a-447d-4ee4-901a-c9511bd81ac8, 3, Finished, Available, Finished, False)
# +--------------------+--------------------+-----------+
# |           namespace|           tableName|isTemporary|
# +--------------------+--------------------+-----------+
# |`Bank_Enhance_Ana...|        bronze_bank_|      false|
# |`Bank_Enhance_Ana...|bronze_bank_marke...|      false|
# |`Bank_Enhance_Ana...|      bronze_channel|      false|
# |`Bank_Enhance_Ana...|     bronze_customer|      false|
# |`Bank_Enhance_Ana...|       bronze_region|      false|
# |`Bank_Enhance_Ana...|gold_campaign_per...|      false|
# |`Bank_Enhance_Ana...|gold_customer_ove...|      false|
# |`Bank_Enhance_Ana...|   gold_risk_revenue|      false|
# |`Bank_Enhance_Ana...|silver_bank_marke...|      false|
# |`Bank_Enhance_Ana...|      silver_channel|      false|
# |`Bank_Enhance_Ana...|     silver_customer|      false|
# |`Bank_Enhance_Ana...|       silver_region|      false|
# ...
